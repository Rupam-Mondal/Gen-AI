# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Line , scatter , bar etc

# %%
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
df = pd.DataFrame(np.random.rand(50), columns=['Data'])

# %%
df.plot(figsize=(20 , 8))
# Out:
# <Axes: >

# %%
#Scatter plot

# %%
# when two value are present in x and y axis
x = [1,2,3,4,5,7,8]
y= [10,12,14,16,15,17,19]
plt.scatter(x , y)

# %%
#Line plot
#When ou want to deplict relation between two variable in form of trend
#mostly in x axis the date - time column is there

# %%
x = [1 , 2 , 3 , 4 , 5] #assume is x no of day
y = [5 , 2 , 7 , 8 , 1] #stock price

# %%
plt.plot(x , y)

# %%
plt.plot(x , y , color="red", marker="o")
plt.title("Line chart to understand the syntax")
plt.xlabel("Day number")
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y1 = [8, 5, 9, 11, 7]
y2 = [9, 7, 5, 6, 10]

# Create a plot with multiple lines
plt.plot(x, y1, marker='o', linestyle=':', color='b', label='Line 1')
plt.plot(x, y2, marker='s', linestyle='--', color='r', label='Line 2')

# Add labels, title, and legend
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple Lines on One Plot")
plt.legend()

# Display the plot
plt.show()
