# %%
import pandas as pd

# %%
"""Pandas is used to analyse data"""

# %%
df = pd.read_csv("name.csv")

# %%
df
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef

# %%
"""
By de fault panda consider first row as first coloum
to neglect that head = None is used
"""

pd.read_csv("name.csv" , header=None)
# Out:
#     0               1    2          3           4
# 0  ID            Name  Age    Country  Occupation
# 1   1        John Doe   28        USA    Engineer
# 2   2      Jane Smith   34     Canada      Doctor
# 3   3       Sam Brown   22         UK     Student
# 4   4     Emily Davis   45  Australia     Teacher
# 5   5  Michael Wilson   30        USA    Designer
# 6   6  Sophia Johnson   27    Germany   Architect
# 7   7     Liam Martin   31     France        Chef

# %%
"""Helps to skip 2 rows from top"""

pd.read_csv("name.csv" , skiprows=2)
# Out:
#    2      Jane Smith  34     Canada     Doctor
# 0  3       Sam Brown  22         UK    Student
# 1  4     Emily Davis  45  Australia    Teacher
# 2  5  Michael Wilson  30        USA   Designer
# 3  6  Sophia Johnson  27    Germany  Architect
# 4  7     Liam Martin  31     France       Chef

# %%
pd.read_csv("name.csv" , usecols=['Name', 'Age'])
# Out:
#              Name  Age
# 0        John Doe   28
# 1      Jane Smith   34
# 2       Sam Brown   22
# 3     Emily Davis   45
# 4  Michael Wilson   30
# 5  Sophia Johnson   27
# 6     Liam Martin   31

# %%
df
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef

# %%
#In pasdas we store data in form series and data form
#series is one dimentional in nature and data frame is 2
#dimentional in nature

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#We can access any coloum by name of the coloum
df.Name
# Out:
# 0          John Doe
# 1        Jane Smith
# 2         Sam Brown
# 3       Emily Davis
# 4    Michael Wilson
# 5    Sophia Johnson
# 6       Liam Martin
# Name: Name, dtype: object

# %%
"""Another way to declare method"""

df["Name"]
# Out:
# 0          John Doe
# 1        Jane Smith
# 2         Sam Brown
# 3       Emily Davis
# 4    Michael Wilson
# 5    Sophia Johnson
# 6       Liam Martin
# Name: Name, dtype: object

# %%
type(df["Name"]) # A coloum is a series in data frame
# Out:
# pandas.core.series.Series

# %%
l = [1 , 2 , 3 , 4]
s = pd.Series(l)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s #Index will be there
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s[0:]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(s[1])
# Out:
# 2

# %%
#By default index are interger
#We can have custom indexex

d = pd.Series([100 , 200 , 300] , index = [2.3 , 4.5 , 1])

# %%
d
# Out:
# 2.3    100
# 4.5    200
# 1.0    300
# dtype: int64

# %%
print(d[2.3])
# Out:
# 100

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
#To see the all index of series
d.index
# Out:
# Index([2.3, 4.5, 1.0], dtype='float64')

# %%
#To reset index

d.reset_index(drop=True)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
d.reset_index(drop=False)
# Out:
#    index    0
# 0    2.3  100
# 1    4.5  200
# 2    1.0  300

# %%
d
# Out:
# 2.3    100
# 4.5    200
# 1.0    300
# dtype: int64

# %%
pd.DataFrame(d)
# Out:
#        0
# 2.3  100
# 4.5  200
# 1.0  300

# %%
df
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef

# %%
#I want first 5 rows

df.head(5)
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer

# %%
df.head(2)
# Out:
#    ID        Name  Age Country Occupation
# 0   1    John Doe   28     USA   Engineer
# 1   2  Jane Smith   34  Canada     Doctor

# %%
df.tail(2)
# Out:
#    ID            Name  Age  Country Occupation
# 5   6  Sophia Johnson   27  Germany  Architect
# 6   7     Liam Martin   31   France       Chef

# %%
df.shape #How many row and coloum are there
# Out:
# (7, 5)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Country', 'Occupation'], dtype='object')

# %%
list(df.columns)
# Out:
# ['ID', 'Name', 'Age', 'Country', 'Occupation']

# %%
df.sample(2) #Gives 2 random rows
# Out:
#    ID            Name  Age  Country Occupation
# 5   6  Sophia Johnson   27  Germany  Architect
# 6   7     Liam Martin   31   France       Chef

# %%
df.info
# Out:
# <bound method DataFrame.info of    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef>

# %%
df.dtypes
# Out:
# ID             int64
# Name          object
# Age            int64
# Country       object
# Occupation    object
# dtype: object

# %%
d
# Out:
# 2.3    100
# 4.5    200
# 1.0    300
# dtype: int64

# %%
d["new coloum"] = "Rupam"

# %%
d
# Out:
# 2.3             100
# 4.5             200
# 1.0             300
# new coloum    Rupam
# dtype: object

# %%
pd.DataFrame(d)
# Out:
#                 0
# 2.3           100
# 4.5           200
# 1.0           300
# new coloum  Rupam

# %%
d["new-coloum"] = "Rupam"

# %%
d
# Out:
# 2.3             100
# 4.5             200
# 1.0             300
# new coloum    Rupam
# new-coloum    Rupam
# dtype: object

# %%
df
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef

# %%
df["new-col"] = "Rupam"

# %%
df
# Out:
#    ID            Name  Age    Country Occupation new-col
# 0   1        John Doe   28        USA   Engineer   Rupam
# 1   2      Jane Smith   34     Canada     Doctor   Rupam
# 2   3       Sam Brown   22         UK    Student   Rupam
# 3   4     Emily Davis   45  Australia    Teacher   Rupam
# 4   5  Michael Wilson   30        USA   Designer   Rupam
# 5   6  Sophia Johnson   27    Germany  Architect   Rupam
# 6   7     Liam Martin   31     France       Chef   Rupam

# %%
df[["Name" , "Age"]] #we can access two simultaneously you have to give 2 brakets
# Out:
#              Name  Age
# 0        John Doe   28
# 1      Jane Smith   34
# 2       Sam Brown   22
# 3     Emily Davis   45
# 4  Michael Wilson   30
# 5  Sophia Johnson   27
# 6     Liam Martin   31

# %%
df1 = pd.read_excel("data.xlsx")

# %%
df1
# Out:
#    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef

# %%
df1.shape
# Out:
# (7, 5)

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Country', 'Occupation'], dtype='object')

# %%
df1.info
# Out:
# <bound method DataFrame.info of    ID            Name  Age    Country Occupation
# 0   1        John Doe   28        USA   Engineer
# 1   2      Jane Smith   34     Canada     Doctor
# 2   3       Sam Brown   22         UK    Student
# 3   4     Emily Davis   45  Australia    Teacher
# 4   5  Michael Wilson   30        USA   Designer
# 5   6  Sophia Johnson   27    Germany  Architect
# 6   7     Liam Martin   31     France       Chef>

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df3.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df3.PassengerId
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
url_df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
url_df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
type(url_df)
# Out:
# list

# %%
#read a json file from url
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/59235  2404776036
# 1     https://github.com/pandas-dev/pandas/pull/59234  2404401505
# 2   https://github.com/pandas-dev/pandas/issues/59233  2404008935
# 3   https://github.com/pandas-dev/pandas/issues/59232  2403560323
# 4   https://github.com/pandas-dev/pandas/issues/59231  2403519741
# 5     https://github.com/pandas-dev/pandas/pull/59228  2403111123
# 6   https://github.com/pandas-dev/pandas/issues/59227  2402933357
# 7   https://github.com/pandas-dev/pandas/issues/59226  2402516336
# 8     https://github.com/pandas-dev/pandas/pull/59225  2402452638
# 9   https://github.com/pandas-dev/pandas/issues/59224  2402069055
# 10    https://github.com/pandas-dev/pandas/pull/59223  2401389538
# 11  https://github.com/pandas-dev/pandas/issues/59222  2400767320
# 12  https://github.com/pandas-dev/pandas/issues/59221  2400641587
# 13    https://github.com/pandas-dev/pandas/pull/59219  2399423860
# 14  https://github.com/pandas-dev/pandas/issues/59218  2399409527
# 15    https://github.com/pandas-dev/pandas/pull/59217  2398844856
# 16    https://github.com/pandas-dev/pandas/pull/59216  2397367000
# 17    https://github.com/pandas-dev/pandas/pull/59215  2397346679
# 18  https://github.com/pandas-dev/pandas/issues/59212  2396391937
# 19    https://github.com/pandas-dev/pandas/pull/59211  2396085734
# 20    https://github.com/pandas-dev/pandas/pull/59210  2396011434
# 21  https://github.com/pandas-dev/pandas/issues/59207  2394929953
# 22    https://github.com/pandas-dev/pandas/pull/59205  2394458920
# 23    https://github.com/pandas-dev/pandas/pull/59197  2393991299
# 24  https://github.com/pandas-dev/pandas/issues/59196  2393772977
# 25  https://github.com/pandas-dev/pandas/issues/59193  2393027517
# 26  https://github.com/pandas-dev/pandas/issues/59192  2392957430
# 27    https://github.com/pandas-dev/pandas/pull/59190  2392774845
# 28    https://github.com/pandas-dev/pandas/pull/59189  2392755723
# 29    https://github.com/pandas-dev/pandas/pull/59188  2392722488
#
#                 node_id  number  \
# 0    I_kwDOAA0YD86PVfhk   59235
# 1   PR_kwDOAA0YD851KTtd   59234
# 2    I_kwDOAA0YD86PSkPn   59233
# 3    I_kwDOAA0YD86PQ2uD   59232
# 4    I_kwDOAA0YD86PQsz9   59231
# 5   PR_kwDOAA0YD851F6M4   59228
# 6    I_kwDOAA0YD86POdpt   59227
# 7    I_kwDOAA0YD86PM31w   59226
# 8   PR_kwDOAA0YD851Dqmz   59225
# 9    I_kwDOAA0YD86PLKo_   59224
# 10  PR_kwDOAA0YD851AI1R   59223
# 11   I_kwDOAA0YD86PGM1Y   59222
# 12   I_kwDOAA0YD86PFuIz   59221
# 13  PR_kwDOAA0YD8505azB   59219
# 14   I_kwDOAA0YD86PBBV3   59218
# 15  PR_kwDOAA0YD8503i82   59217
# 16  PR_kwDOAA0YD850ycA0   59216
# 17  PR_kwDOAA0YD850yXmN   59215
# 18   I_kwDOAA0YD86O1goB   59212
# 19  PR_kwDOAA0YD850uC-h   59211
# 20  PR_kwDOAA0YD850tyzL   59210
# 21   I_kwDOAA0YD86Ov7sh   59207
# 22  PR_kwDOAA0YD850od5m   59205
# 23  PR_kwDOAA0YD850nCWD   59197
# 24   I_kwDOAA0YD86OrhOx   59196
# 25   I_kwDOAA0YD86OorO9   59193
# 26   I_kwDOAA0YD86OoaH2   59192
# 27  PR_kwDOAA0YD850jB57   59190
# 28  PR_kwDOAA0YD850i9yQ   59189
# 29  PR_kwDOAA0YD850i2j4   59188
#
#                                                 title  ... closed_at  \
# 0   ENH: Consistent API between `pd.get_dummies()`...  ...       NaT
# 1                  BUG/TST: non-numeric EA reductions  ...       NaT
# 2         BUG: json_normalize KeyError Key not found   ...       NaT
# 3             DOC: "list" is not a keyword - .query()  ...       NaT
# 4          DOC: sentence fragment in "String methods"  ...       NaT
# 5   CLN: enforce the deprecation ofaccepting Manag...  ...       NaT
# 6   BUG: AttributeError about dateutil.relativedel...  ...       NaT
# 7   ENH: is it worth fixing a warning from a third...  ...       NaT
# 8   BUG: fix json_normalize with meta far differen...  ...       NaT
# 9                                 BUG: SQL connection  ...       NaT
# 10  Edited note on index_col/parse_dates params fo...  ...       NaT
# 11  BUG: unexpected behavior when Loading lines li...  ...       NaT
# 12  ENH: Replacing behavior currently provided by ...  ...       NaT
# 13             BUG: Fix read_csv index dtype override  ...       NaT
# 14  BUG: `pandas.tseries.frequencies.to_offset()` ...  ...       NaT
# 15     fix-issue-59196: add extra check for np arrays  ...       NaT
# 16  DOC: add SA01 for pandas.api.types.is_int64_dtype  ...       NaT
# 17  DOC: add SA01 for pandas.api.types.is_extensio...  ...       NaT
# 18  BUG: regression in master for DataFrame.sparse...  ...       NaT
# 19             BUG: .plot(kind='pie') with ArrowDtype  ...       NaT
# 20                           CLN: More read_csv state  ...       NaT
# 21  ENH: Extend to_numeric to Convert Hexadecimal,...  ...       NaT
# 22             ENH: dt.day_of_week should return int8  ...       NaT
# 23                  Pyarrow series .any() Error fixed  ...       NaT
# 24  BUG: ValueError when accessing dataFrame with ...  ...       NaT
# 25  ENH: Pipe `attrs` to_html Jinja2 environmental...  ...       NaT
# 26  BUG: Pyarrow series .any() returns a bool, mes...  ...       NaT
# 27  DataFrameGroupBy.agg with nan results error Fixed  ...       NaT
# 28                         DataFrame.eval error fixed  ...       NaT
# 29  Difference between calamine and openpyxl reade...  ...       NaT
#
#    author_association active_lock_reason  \
# 0         CONTRIBUTOR                NaN
# 1              MEMBER                NaN
# 2                NONE                NaN
# 3         CONTRIBUTOR                NaN
# 4         CONTRIBUTOR                NaN
# 5         CONTRIBUTOR                NaN
# 6                NONE                NaN
# 7                NONE                NaN
# 8                NONE                NaN
# 9                NONE                NaN
# 10               NONE                NaN
# 11               NONE                NaN
# 12               NONE                NaN
# 13               NONE                NaN
# 14               NONE                NaN
# 15               NONE                NaN
# 16               NONE                NaN
# 17               NONE                NaN
# 18               NONE                NaN
# 19             MEMBER                NaN
# 20             MEMBER                NaN
# 21               NONE                NaN
# 22        CONTRIBUTOR                NaN
# 23               NONE                NaN
# 24               NONE                NaN
# 25               NONE                NaN
# 26               NONE                NaN
# 27               NONE                NaN
# 28               NONE                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 1   - [x] [Tests added and passed](https://pandas....
# 2   ### Pandas version checks\n\n- [X] I have chec...
# 3   > Column names which are Python keywords (like...
# 4   https://github.com/pandas-dev/pandas/blob/d966...
# 5   enforced the deprecation of accepting Manager ...
# 6   ### Pandas version checks\r\n\r\n- [X] I have ...
# 7   ### Feature Type\n\n- [ ] Adding new functiona...
# 8   - fix of json_normalize when record_path long ...
# 9   ### Pandas version checks\r\n\r\n- [X] I have ...
# 10  (The sentence as it stands is missing a verb; ...
# 11  ### Pandas version checks\r\n\r\n- [X] I have ...
# 12  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 13  - [x] closes #59077\r\n- [x] [Tests added and ...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  - [x] closes #59196 (Replace xxxx with the Git...
# 16  part of https://github.com/pandas-dev/pandas/i...
# 17  part of #58577\r\n\r\n``` -i "pandas.api.types...
# 18  ### Pandas version checks\r\n\r\n- [X] I have ...
# 19  - [ ] closes #59192 (Replace xxxx with the Git...
# 20     Also inlines some single use methods/functions
# 21  ### Feature Type\n\n- [ ] Adding new functiona...
# 22  - [X] closes #58185\r\n- [ ] [Tests added and ...
# 23  - [ ] closes #59192  (Replace xxxx with the Gi...
# 24  ### Pandas version checks\n\n- [X] I have chec...
# 25  ### Feature Type\n\n- [ ] Adding new functiona...
# 26  ### Pandas version checks\n\n- [X] I have chec...
# 27  - [#59106 ] closes #59106  (Replace xxxx with ...
# 28  - [#59062 ] closes #59062  (Replace xxxx with ...
# 29  - [ #59186 ] closes #59186  (Replace xxxx with...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   NaN
# 3                       NaN           NaN   NaN
# 4                       NaN           NaN   NaN
# 5                       NaN           NaN   1.0
# 6                       NaN           NaN   NaN
# 7                       NaN           NaN   NaN
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   NaN
# 10                      NaN           NaN   0.0
# 11                      NaN           NaN   NaN
# 12                      NaN           NaN   NaN
# 13                      NaN           NaN   0.0
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   0.0
# 16                      NaN           NaN   0.0
# 17                      NaN           NaN   0.0
# 18                      NaN           NaN   NaN
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   0.0
# 21                      NaN           NaN   NaN
# 22                      NaN           NaN   1.0
# 23                      NaN           NaN   0.0
# 24                      NaN           NaN   NaN
# 25                      NaN           NaN   NaN
# 26                      NaN           NaN   NaN
# 27                      NaN           NaN   0.0
# 28                      NaN           NaN   0.0
# 29                      NaN           NaN   0.0
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
# [30 rows x 30 columns]
